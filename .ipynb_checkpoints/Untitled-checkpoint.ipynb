# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import trimesh
from pyntcloud import PyntCloud

# %%
'''
Normalization:

Ensure all models are scaled and centered in a consistent coordinate space.
Simplification:

Reduce the number of vertices and faces for computational efficiency while retaining key details.
'''

# %%
# Load the 3D model
mesh = trimesh.load("3d_objects/cube_1.obj")
mesh
# Out:
# <trimesh.Trimesh(vertices.shape=(8, 3), faces.shape=(12, 3), name=`cube_1.obj`)>

# %%
# Convert to point cloud
point_cloud = mesh.sample(10000)
point_cloud
# Out:
# TrackedArray([[-0.07230331, -1.26236851,  0.64993971],
#               [-0.59735741,  1.1924796 , -0.1088775 ],
#               [-1.11985399, -0.36961479, -0.53691168],
#               ...,
#               [-1.04515648,  0.89760211,  0.00458168],
#               [-1.27511239, -0.26188723, -0.06999455],
#               [-0.14673181, -1.12009663,  0.68429225]])

# %%
centroid = np.mean(point_cloud, axis=0)
centroid
# Out:
# TrackedArray([ 0.00979664, -0.00778833, -0.00586409])

# %%
# Plot the point cloud and centroid

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(point_cloud[:, 0], point_cloud[:, 1], point_cloud[:, 2], s=1, label="Point Cloud")

ax.scatter(centroid[0], centroid[1], centroid[2], color='red', s=10, label="Centroid")

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.legend()

plt.show()
